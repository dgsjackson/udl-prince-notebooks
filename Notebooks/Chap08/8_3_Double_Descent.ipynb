# %% [markdown]
# <a href="https://colab.research.google.com/github/dgsjackson/udl-prince-notebooks/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-v92hy8z0
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-v92hy8z0
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=ab456bab62bd534cda460b44d03b3e97afa73261b4e5b3af4ebffc406b41c505
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v_987kmx/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304925, train error 89.70,  test loss 2.305177, test error 90.18
# Epoch   100, train loss 1.896019, train error 71.38,  test loss 1.751982, test error 68.97
# Epoch   200, train loss 1.853014, train error 70.95,  test loss 1.688350, test error 68.07
# Epoch   300, train loss 1.850981, train error 70.53,  test loss 1.698434, test error 68.35
# Epoch   400, train loss 1.852112, train error 70.15,  test loss 1.697305, test error 68.62
# Epoch   500, train loss 1.852284, train error 70.32,  test loss 1.702842, test error 67.22
# Epoch   600, train loss 1.845937, train error 70.05,  test loss 1.689425, test error 67.25
# Epoch   700, train loss 1.846283, train error 70.03,  test loss 1.700618, test error 67.90
# Epoch   800, train loss 1.844095, train error 70.12,  test loss 1.693040, test error 67.82
# Epoch   900, train loss 1.843501, train error 69.75,  test loss 1.690093, test error 67.93
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302454, train error 88.60,  test loss 2.299920, test error 89.35
# Epoch   100, train loss 1.804515, train error 66.20,  test loss 1.667068, test error 64.15
# Epoch   200, train loss 1.767476, train error 65.22,  test loss 1.631162, test error 63.10
# Epoch   300, train loss 1.759020, train error 66.12,  test loss 1.616027, test error 63.28
# Epoch   400, train loss 1.751473, train error 64.93,  test loss 1.615057, test error 63.45
# Epoch   500, train loss 1.746522, train error 64.93,  test loss 1.602372, test error 62.62
# Epoch   600, train loss 1.746094, train error 64.78,  test loss 1.597302, test error 62.03
# Epoch   700, train loss 1.748455, train error 64.43,  test loss 1.601082, test error 62.80
# Epoch   800, train loss 1.757840, train error 65.40,  test loss 1.624936, test error 62.92
# Epoch   900, train loss 1.744422, train error 64.70,  test loss 1.601214, test error 62.35
# Training model with   6 hidden variables
# Epoch     0, train loss 2.224857, train error 80.70,  test loss 2.202778, test error 79.35
# Epoch   100, train loss 1.688462, train error 60.62,  test loss 1.530815, test error 59.25
# Epoch   200, train loss 1.613520, train error 55.88,  test loss 1.443720, test error 54.72
# Epoch   300, train loss 1.596999, train error 55.83,  test loss 1.437055, test error 55.30
# Epoch   400, train loss 1.587153, train error 56.05,  test loss 1.437486, test error 54.60
# Epoch   500, train loss 1.578457, train error 55.80,  test loss 1.434119, test error 54.28
# Epoch   600, train loss 1.577858, train error 56.00,  test loss 1.439467, test error 54.72
# Epoch   700, train loss 1.574184, train error 56.17,  test loss 1.442278, test error 55.03
# Epoch   800, train loss 1.573389, train error 55.83,  test loss 1.443704, test error 55.22
# Epoch   900, train loss 1.575020, train error 55.90,  test loss 1.435642, test error 54.78
# Training model with   8 hidden variables
# Epoch     0, train loss 2.307807, train error 90.25,  test loss 2.311089, test error 90.20
# Epoch   100, train loss 1.666713, train error 59.10,  test loss 1.510905, test error 59.78
# Epoch   200, train loss 1.635691, train error 57.72,  test loss 1.511675, test error 59.28
# Epoch   300, train loss 1.607729, train error 56.55,  test loss 1.490372, test error 57.50
# Epoch   400, train loss 1.581443, train error 55.25,  test loss 1.470500, test error 55.90
# Epoch   500, train loss 1.573122, train error 54.33,  test loss 1.469529, test error 54.95
# Epoch   600, train loss 1.575492, train error 55.22,  test loss 1.470501, test error 54.72
# Epoch   700, train loss 1.563908, train error 54.50,  test loss 1.473046, test error 54.72
# Epoch   800, train loss 1.562632, train error 54.65,  test loss 1.471622, test error 55.05
# Epoch   900, train loss 1.567236, train error 54.90,  test loss 1.476445, test error 55.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.163686, train error 80.72,  test loss 2.118126, test error 79.10
# Epoch   100, train loss 1.456722, train error 48.90,  test loss 1.262471, test error 46.53
# Epoch   200, train loss 1.394955, train error 47.20,  test loss 1.256720, test error 46.05
# Epoch   300, train loss 1.378717, train error 46.62,  test loss 1.269886, test error 46.35
# Epoch   400, train loss 1.365206, train error 46.90,  test loss 1.294458, test error 47.00
# Epoch   500, train loss 1.352973, train error 46.22,  test loss 1.305698, test error 46.92
# Epoch   600, train loss 1.351737, train error 45.97,  test loss 1.316815, test error 47.72
# Epoch   700, train loss 1.346842, train error 45.72,  test loss 1.331641, test error 47.22
# Epoch   800, train loss 1.351265, train error 45.72,  test loss 1.350092, test error 47.35
# Epoch   900, train loss 1.341036, train error 45.55,  test loss 1.360785, test error 47.58
# Training model with  14 hidden variables
# Epoch     0, train loss 2.178338, train error 81.18,  test loss 2.148551, test error 79.80
# Epoch   100, train loss 1.403800, train error 46.85,  test loss 1.295584, test error 49.28
# Epoch   200, train loss 1.355063, train error 45.03,  test loss 1.313767, test error 49.47
# Epoch   300, train loss 1.333371, train error 44.83,  test loss 1.320294, test error 49.80
# Epoch   400, train loss 1.311867, train error 43.88,  test loss 1.330220, test error 49.62
# Epoch   500, train loss 1.308379, train error 44.45,  test loss 1.368357, test error 50.33
# Epoch   600, train loss 1.287579, train error 43.40,  test loss 1.355384, test error 49.88
# Epoch   700, train loss 1.277878, train error 43.10,  test loss 1.365892, test error 50.03
# Epoch   800, train loss 1.263026, train error 43.17,  test loss 1.363080, test error 50.12
# Epoch   900, train loss 1.263716, train error 42.78,  test loss 1.382664, test error 50.03
# Training model with  18 hidden variables
# Epoch     0, train loss 2.188067, train error 79.18,  test loss 2.164975, test error 79.95
# Epoch   100, train loss 1.323172, train error 43.62,  test loss 1.315516, test error 49.83
# Epoch   200, train loss 1.223995, train error 40.70,  test loss 1.341767, test error 49.38
# Epoch   300, train loss 1.177452, train error 39.38,  test loss 1.392527, test error 49.78
# Epoch   400, train loss 1.163746, train error 38.92,  test loss 1.424905, test error 50.62
# Epoch   500, train loss 1.147164, train error 38.20,  test loss 1.453037, test error 51.38
# Epoch   600, train loss 1.130163, train error 37.08,  test loss 1.477680, test error 51.45
# Epoch   700, train loss 1.127246, train error 37.38,  test loss 1.504218, test error 51.40
# Epoch   800, train loss 1.118050, train error 36.88,  test loss 1.516720, test error 51.97
# Epoch   900, train loss 1.102761, train error 36.55,  test loss 1.540195, test error 51.70
# Training model with  22 hidden variables
# Epoch     0, train loss 2.213800, train error 81.35,  test loss 2.207375, test error 81.22
# Epoch   100, train loss 1.261375, train error 41.47,  test loss 1.326212, test error 49.42
# Epoch   200, train loss 1.139067, train error 37.97,  test loss 1.388405, test error 49.83
# Epoch   300, train loss 1.095275, train error 36.40,  test loss 1.455288, test error 49.88
# Epoch   400, train loss 1.062777, train error 36.20,  test loss 1.512482, test error 50.95
# Epoch   500, train loss 1.043796, train error 35.07,  test loss 1.558104, test error 51.22
# Epoch   600, train loss 1.025043, train error 34.72,  test loss 1.570163, test error 51.33
# Epoch   700, train loss 1.014722, train error 34.45,  test loss 1.621464, test error 52.85
# Epoch   800, train loss 1.018280, train error 34.15,  test loss 1.659275, test error 53.25
# Epoch   900, train loss 0.987355, train error 33.50,  test loss 1.677177, test error 53.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.154816, train error 81.30,  test loss 2.148295, test error 81.25
# Epoch   100, train loss 1.246541, train error 41.75,  test loss 1.382270, test error 52.10
# Epoch   200, train loss 1.098623, train error 36.62,  test loss 1.487892, test error 52.40
# Epoch   300, train loss 1.007185, train error 34.22,  test loss 1.587513, test error 53.78
# Epoch   400, train loss 0.957221, train error 32.53,  test loss 1.688531, test error 53.65
# Epoch   500, train loss 0.939414, train error 32.00,  test loss 1.803730, test error 54.35
# Epoch   600, train loss 0.907003, train error 31.18,  test loss 1.875587, test error 53.65
# Epoch   700, train loss 0.890110, train error 31.05,  test loss 1.962944, test error 55.03
# Epoch   800, train loss 0.891501, train error 31.22,  test loss 2.055760, test error 55.53
# Epoch   900, train loss 0.874325, train error 30.80,  test loss 2.072664, test error 55.60
# Training model with  30 hidden variables
# Epoch     0, train loss 2.165984, train error 80.20,  test loss 2.145320, test error 78.93
# Epoch   100, train loss 1.113559, train error 35.78,  test loss 1.321774, test error 47.90
# Epoch   200, train loss 0.951053, train error 31.03,  test loss 1.510425, test error 51.03
# Epoch   300, train loss 0.865993, train error 28.57,  test loss 1.650720, test error 50.78
# Epoch   400, train loss 0.797697, train error 26.30,  test loss 1.789950, test error 51.70
# Epoch   500, train loss 0.755515, train error 25.07,  test loss 1.957114, test error 53.30
# Epoch   600, train loss 0.726894, train error 24.55,  test loss 2.079441, test error 53.30
# Epoch   700, train loss 0.706960, train error 24.32,  test loss 2.206325, test error 54.20
# Epoch   800, train loss 0.694995, train error 24.00,  test loss 2.326812, test error 54.72
# Epoch   900, train loss 0.679072, train error 23.22,  test loss 2.424245, test error 54.25
# Training model with  35 hidden variables
# Epoch     0, train loss 2.155480, train error 77.75,  test loss 2.138174, test error 77.78
# Epoch   100, train loss 0.993473, train error 32.20,  test loss 1.347004, test error 47.20
# Epoch   200, train loss 0.740211, train error 23.28,  test loss 1.666169, test error 50.25
# Epoch   300, train loss 0.599189, train error 19.25,  test loss 2.161293, test error 52.33
# Epoch   400, train loss 0.546676, train error 18.12,  test loss 2.583833, test error 52.97
# Epoch   500, train loss 0.511146, train error 16.78,  test loss 3.010732, test error 53.03
# Epoch   600, train loss 0.475996, train error 15.95,  test loss 3.318180, test error 52.97
# Epoch   700, train loss 0.462552, train error 15.45,  test loss 3.732598, test error 54.47
# Epoch   800, train loss 0.407662, train error 13.20,  test loss 4.051058, test error 55.00
# Epoch   900, train loss 0.418860, train error 14.78,  test loss 4.288444, test error 53.80
# Training model with  40 hidden variables
# Epoch     0, train loss 2.151077, train error 80.35,  test loss 2.132233, test error 79.47
# Epoch   100, train loss 0.952954, train error 30.82,  test loss 1.388944, test error 48.95
# Epoch   200, train loss 0.684439, train error 22.15,  test loss 1.866655, test error 51.08
# Epoch   300, train loss 0.518620, train error 16.55,  test loss 2.489457, test error 53.75
# Epoch   400, train loss 0.453016, train error 15.43,  test loss 3.119138, test error 55.05
# Epoch   500, train loss 0.382972, train error 13.40,  test loss 3.748256, test error 56.60
# Epoch   600, train loss 0.332665, train error 11.22,  test loss 4.381557, test error 56.05
# Epoch   700, train loss 0.299392, train error 10.82,  test loss 5.127598, test error 56.83
# Epoch   800, train loss 0.247770, train error 8.53,  test loss 5.771715, test error 57.17
# Epoch   900, train loss 0.233969, train error 8.03,  test loss 6.368895, test error 55.97
# Training model with  45 hidden variables
# Epoch     0, train loss 2.117464, train error 77.07,  test loss 2.081661, test error 77.35
# Epoch   100, train loss 0.793228, train error 25.20,  test loss 1.457879, test error 49.08
# Epoch   200, train loss 0.501321, train error 16.40,  test loss 2.236284, test error 51.72
# Epoch   300, train loss 0.292453, train error 8.68,  test loss 3.300268, test error 53.72
# Epoch   400, train loss 0.222085, train error 7.28,  test loss 4.735264, test error 55.72
# Epoch   500, train loss 0.143280, train error 4.75,  test loss 5.904352, test error 55.03
# Epoch   600, train loss 0.176074, train error 6.12,  test loss 7.270733, test error 55.45
# Epoch   700, train loss 0.010083, train error 0.00,  test loss 8.178037, test error 55.20
# Epoch   800, train loss 0.006950, train error 0.00,  test loss 8.795067, test error 55.45
# Epoch   900, train loss 0.005295, train error 0.00,  test loss 9.253305, test error 55.55
# Training model with  50 hidden variables
# Epoch     0, train loss 2.108277, train error 76.85,  test loss 2.084796, test error 78.15
# Epoch   100, train loss 0.701117, train error 22.45,  test loss 1.511677, test error 49.62
# Epoch   200, train loss 0.325631, train error 9.78,  test loss 2.573992, test error 53.38
# Epoch   300, train loss 0.136795, train error 2.82,  test loss 4.200554, test error 55.12
# Epoch   400, train loss 0.027598, train error 0.03,  test loss 5.727928, test error 55.45
# Epoch   500, train loss 0.012768, train error 0.00,  test loss 6.620311, test error 55.72
# Epoch   600, train loss 0.008218, train error 0.00,  test loss 7.235181, test error 55.67
# Epoch   700, train loss 0.005921, train error 0.00,  test loss 7.691594, test error 55.92
# Epoch   800, train loss 0.004585, train error 0.00,  test loss 8.057546, test error 56.08
# Epoch   900, train loss 0.003694, train error 0.00,  test loss 8.366323, test error 55.97
# Training model with  55 hidden variables
# Epoch     0, train loss 2.036864, train error 76.93,  test loss 1.982834, test error 78.30
# Epoch   100, train loss 0.669575, train error 20.32,  test loss 1.636342, test error 50.62
# Epoch   200, train loss 0.255610, train error 6.60,  test loss 2.965844, test error 54.72
# Epoch   300, train loss 0.077739, train error 0.80,  test loss 4.705266, test error 55.38
# Epoch   400, train loss 0.017407, train error 0.00,  test loss 5.929377, test error 56.00
# Epoch   500, train loss 0.009461, train error 0.00,  test loss 6.635303, test error 56.17
# Epoch   600, train loss 0.006346, train error 0.00,  test loss 7.140632, test error 56.12
# Epoch   700, train loss 0.004711, train error 0.00,  test loss 7.522616, test error 56.05
# Epoch   800, train loss 0.003731, train error 0.00,  test loss 7.830116, test error 56.00
# Epoch   900, train loss 0.003031, train error 0.00,  test loss 8.088605, test error 55.88
# Training model with  60 hidden variables
# Epoch     0, train loss 2.067493, train error 77.57,  test loss 2.027406, test error 77.62
# Epoch   100, train loss 0.503464, train error 15.35,  test loss 1.793326, test error 51.65
# Epoch   200, train loss 0.084890, train error 0.55,  test loss 3.498180, test error 54.30
# Epoch   300, train loss 0.018323, train error 0.00,  test loss 4.730652, test error 54.88
# Epoch   400, train loss 0.008824, train error 0.00,  test loss 5.363480, test error 54.62
# Epoch   500, train loss 0.005635, train error 0.00,  test loss 5.799677, test error 54.50
# Epoch   600, train loss 0.004074, train error 0.00,  test loss 6.117678, test error 54.65
# Epoch   700, train loss 0.003145, train error 0.00,  test loss 6.375509, test error 54.70
# Epoch   800, train loss 0.002536, train error 0.00,  test loss 6.587528, test error 54.67
# Epoch   900, train loss 0.002113, train error 0.00,  test loss 6.769624, test error 54.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.037942, train error 75.32,  test loss 1.959873, test error 75.80
# Epoch   100, train loss 0.414425, train error 11.15,  test loss 1.879902, test error 51.75
# Epoch   200, train loss 0.037315, train error 0.00,  test loss 3.502026, test error 53.25
# Epoch   300, train loss 0.011954, train error 0.00,  test loss 4.337599, test error 53.22
# Epoch   400, train loss 0.006535, train error 0.00,  test loss 4.797628, test error 53.22
# Epoch   500, train loss 0.004360, train error 0.00,  test loss 5.118257, test error 53.38
# Epoch   600, train loss 0.003221, train error 0.00,  test loss 5.357288, test error 53.40
# Epoch   700, train loss 0.002520, train error 0.00,  test loss 5.552507, test error 53.53
# Epoch   800, train loss 0.002052, train error 0.00,  test loss 5.717164, test error 53.42
# Epoch   900, train loss 0.001722, train error 0.00,  test loss 5.857143, test error 53.42
# Training model with  80 hidden variables
# Epoch     0, train loss 2.010671, train error 74.78,  test loss 1.952171, test error 74.28
# Epoch   100, train loss 0.223936, train error 3.00,  test loss 1.980021, test error 50.65
# Epoch   200, train loss 0.020290, train error 0.00,  test loss 3.242094, test error 52.03
# Epoch   300, train loss 0.008015, train error 0.00,  test loss 3.775710, test error 52.45
# Epoch   400, train loss 0.004758, train error 0.00,  test loss 4.090247, test error 52.62
# Epoch   500, train loss 0.003283, train error 0.00,  test loss 4.317858, test error 52.75
# Epoch   600, train loss 0.002471, train error 0.00,  test loss 4.491854, test error 52.75
# Epoch   700, train loss 0.001963, train error 0.00,  test loss 4.630970, test error 52.83
# Epoch   800, train loss 0.001618, train error 0.00,  test loss 4.752264, test error 52.83
# Epoch   900, train loss 0.001368, train error 0.00,  test loss 4.854074, test error 52.90
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020666, train error 74.55,  test loss 1.960926, test error 74.38
# Epoch   100, train loss 0.143873, train error 1.00,  test loss 2.114028, test error 51.22
# Epoch   200, train loss 0.015419, train error 0.00,  test loss 3.149060, test error 51.78
# Epoch   300, train loss 0.006739, train error 0.00,  test loss 3.581012, test error 51.62
# Epoch   400, train loss 0.004105, train error 0.00,  test loss 3.845859, test error 51.65
# Epoch   500, train loss 0.002872, train error 0.00,  test loss 4.034804, test error 51.75
# Epoch   600, train loss 0.002180, train error 0.00,  test loss 4.183198, test error 51.78
# Epoch   700, train loss 0.001744, train error 0.00,  test loss 4.303494, test error 51.75
# Epoch   800, train loss 0.001442, train error 0.00,  test loss 4.405701, test error 51.80
# Epoch   900, train loss 0.001224, train error 0.00,  test loss 4.494870, test error 51.85
# Training model with 100 hidden variables
# Epoch     0, train loss 1.994529, train error 75.28,  test loss 1.939439, test error 75.40
# Epoch   100, train loss 0.094454, train error 0.20,  test loss 2.291082, test error 52.28
# Epoch   200, train loss 0.012123, train error 0.00,  test loss 3.195052, test error 52.60
# Epoch   300, train loss 0.005637, train error 0.00,  test loss 3.575251, test error 52.65
# Epoch   400, train loss 0.003507, train error 0.00,  test loss 3.818758, test error 52.53
# Epoch   500, train loss 0.002492, train error 0.00,  test loss 3.992654, test error 52.58
# Epoch   600, train loss 0.001907, train error 0.00,  test loss 4.129663, test error 52.58
# Epoch   700, train loss 0.001532, train error 0.00,  test loss 4.242772, test error 52.75
# Epoch   800, train loss 0.001274, train error 0.00,  test loss 4.338590, test error 52.65
# Epoch   900, train loss 0.001084, train error 0.00,  test loss 4.421876, test error 52.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975345, train error 73.62,  test loss 1.924954, test error 74.05
# Epoch   100, train loss 0.050974, train error 0.00,  test loss 2.289798, test error 50.62
# Epoch   200, train loss 0.009467, train error 0.00,  test loss 2.948407, test error 51.30
# Epoch   300, train loss 0.004656, train error 0.00,  test loss 3.238420, test error 51.03
# Epoch   400, train loss 0.002974, train error 0.00,  test loss 3.427442, test error 51.15
# Epoch   500, train loss 0.002143, train error 0.00,  test loss 3.566340, test error 51.03
# Epoch   600, train loss 0.001656, train error 0.00,  test loss 3.676703, test error 50.83
# Epoch   700, train loss 0.001339, train error 0.00,  test loss 3.767364, test error 50.80
# Epoch   800, train loss 0.001117, train error 0.00,  test loss 3.845227, test error 50.78
# Epoch   900, train loss 0.000955, train error 0.00,  test loss 3.912821, test error 50.72
# Training model with 140 hidden variables
# Epoch     0, train loss 1.966544, train error 73.32,  test loss 1.894680, test error 72.15
# Epoch   100, train loss 0.037901, train error 0.00,  test loss 2.047890, test error 47.97
# Epoch   200, train loss 0.008143, train error 0.00,  test loss 2.485417, test error 47.80
# Epoch   300, train loss 0.004152, train error 0.00,  test loss 2.702065, test error 48.08
# Epoch   400, train loss 0.002686, train error 0.00,  test loss 2.842640, test error 48.00
# Epoch   500, train loss 0.001950, train error 0.00,  test loss 2.946865, test error 48.10
# Epoch   600, train loss 0.001513, train error 0.00,  test loss 3.029602, test error 48.17
# Epoch   700, train loss 0.001228, train error 0.00,  test loss 3.097569, test error 48.10
# Epoch   800, train loss 0.001027, train error 0.00,  test loss 3.156260, test error 48.12
# Epoch   900, train loss 0.000880, train error 0.00,  test loss 3.207261, test error 48.17
# Training model with 160 hidden variables
# Epoch     0, train loss 1.922708, train error 69.12,  test loss 1.854156, test error 71.28
# Epoch   100, train loss 0.028457, train error 0.00,  test loss 2.169397, test error 50.33
# Epoch   200, train loss 0.007097, train error 0.00,  test loss 2.573372, test error 50.08
# Epoch   300, train loss 0.003733, train error 0.00,  test loss 2.771062, test error 50.00
# Epoch   400, train loss 0.002453, train error 0.00,  test loss 2.903678, test error 49.97
# Epoch   500, train loss 0.001796, train error 0.00,  test loss 3.002146, test error 49.92
# Epoch   600, train loss 0.001403, train error 0.00,  test loss 3.081783, test error 49.95
# Epoch   700, train loss 0.001143, train error 0.00,  test loss 3.147509, test error 50.00
# Epoch   800, train loss 0.000959, train error 0.00,  test loss 3.202463, test error 49.95
# Epoch   900, train loss 0.000823, train error 0.00,  test loss 3.251203, test error 49.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.946826, train error 71.95,  test loss 1.887410, test error 72.32
# Epoch   100, train loss 0.024647, train error 0.00,  test loss 2.051804, test error 48.35
# Epoch   200, train loss 0.006661, train error 0.00,  test loss 2.411265, test error 48.35
# Epoch   300, train loss 0.003568, train error 0.00,  test loss 2.593099, test error 48.47
# Epoch   400, train loss 0.002362, train error 0.00,  test loss 2.714831, test error 48.45
# Epoch   500, train loss 0.001737, train error 0.00,  test loss 2.806824, test error 48.60
# Epoch   600, train loss 0.001360, train error 0.00,  test loss 2.880846, test error 48.50
# Epoch   700, train loss 0.001110, train error 0.00,  test loss 2.942322, test error 48.65
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 2.994730, test error 48.58
# Epoch   900, train loss 0.000802, train error 0.00,  test loss 3.040725, test error 48.58
# Training model with 200 hidden variables
# Epoch     0, train loss 1.912081, train error 71.28,  test loss 1.857902, test error 72.25
# Epoch   100, train loss 0.020286, train error 0.00,  test loss 2.039484, test error 47.65
# Epoch   200, train loss 0.005932, train error 0.00,  test loss 2.353268, test error 47.53
# Epoch   300, train loss 0.003245, train error 0.00,  test loss 2.518715, test error 47.70
# Epoch   400, train loss 0.002170, train error 0.00,  test loss 2.629634, test error 47.62
# Epoch   500, train loss 0.001605, train error 0.00,  test loss 2.713738, test error 47.83
# Epoch   600, train loss 0.001262, train error 0.00,  test loss 2.781819, test error 47.90
# Epoch   700, train loss 0.001033, train error 0.00,  test loss 2.838824, test error 47.90
# Epoch   800, train loss 0.000870, train error 0.00,  test loss 2.887156, test error 47.95
# Epoch   900, train loss 0.000749, train error 0.00,  test loss 2.929935, test error 47.90
# Training model with 250 hidden variables
# Epoch     0, train loss 1.902540, train error 70.03,  test loss 1.829754, test error 71.28
# Epoch   100, train loss 0.017145, train error 0.00,  test loss 1.933382, test error 47.58
# Epoch   200, train loss 0.005393, train error 0.00,  test loss 2.193063, test error 47.90
# Epoch   300, train loss 0.003003, train error 0.00,  test loss 2.329693, test error 47.70
# Epoch   400, train loss 0.002026, train error 0.00,  test loss 2.421648, test error 47.62
# Epoch   500, train loss 0.001508, train error 0.00,  test loss 2.491663, test error 47.72
# Epoch   600, train loss 0.001190, train error 0.00,  test loss 2.548364, test error 47.62
# Epoch   700, train loss 0.000977, train error 0.00,  test loss 2.596610, test error 47.67
# Epoch   800, train loss 0.000825, train error 0.00,  test loss 2.637508, test error 47.78
# Epoch   900, train loss 0.000712, train error 0.00,  test loss 2.672930, test error 47.75
# Training model with 300 hidden variables
# Epoch     0, train loss 1.897150, train error 69.00,  test loss 1.830086, test error 71.12
# Epoch   100, train loss 0.014734, train error 0.00,  test loss 1.867899, test error 47.05
# Epoch   200, train loss 0.004896, train error 0.00,  test loss 2.090288, test error 46.95
# Epoch   300, train loss 0.002777, train error 0.00,  test loss 2.212161, test error 47.12
# Epoch   400, train loss 0.001889, train error 0.00,  test loss 2.296144, test error 47.08
# Epoch   500, train loss 0.001413, train error 0.00,  test loss 2.360088, test error 47.12
# Epoch   600, train loss 0.001119, train error 0.00,  test loss 2.411416, test error 47.12
# Epoch   700, train loss 0.000921, train error 0.00,  test loss 2.453885, test error 47.10
# Epoch   800, train loss 0.000779, train error 0.00,  test loss 2.491234, test error 47.08
# Epoch   900, train loss 0.000673, train error 0.00,  test loss 2.523720, test error 47.08
# Training model with 400 hidden variables
# Epoch     0, train loss 1.837136, train error 66.30,  test loss 1.760372, test error 67.88
# Epoch   100, train loss 0.011644, train error 0.00,  test loss 1.773117, test error 47.00
# Epoch   200, train loss 0.004125, train error 0.00,  test loss 1.949504, test error 46.70
# Epoch   300, train loss 0.002388, train error 0.00,  test loss 2.046017, test error 46.60
# Epoch   400, train loss 0.001644, train error 0.00,  test loss 2.115587, test error 46.72
# Epoch   500, train loss 0.001239, train error 0.00,  test loss 2.168541, test error 46.75
# Epoch   600, train loss 0.000986, train error 0.00,  test loss 2.211642, test error 46.78
# Epoch   700, train loss 0.000815, train error 0.00,  test loss 2.247791, test error 46.70
# Epoch   800, train loss 0.000692, train error 0.00,  test loss 2.279034, test error 46.67
# Epoch   900, train loss 0.000599, train error 0.00,  test loss 2.306638, test error 46.75

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
