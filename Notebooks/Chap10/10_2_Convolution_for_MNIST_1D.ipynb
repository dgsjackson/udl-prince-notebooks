# %% [markdown]
# <a href="https://colab.research.google.com/github/dgsjackson/udl-prince-notebooks/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-x575v6m4
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-x575v6m4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=032cc1aa98940e61b94b5fd4f945414c82b14e784ebe9063fe60b3aafe9c0286
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6q2uqvb3/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(1, 15, 3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(15, 15, 3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(15, 15, 3, stride=2, padding="valid"),
nn.ReLU(),
                       nn.Flatten(),
nn.Linear(60, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.188753, train error 83.28,  val loss 2.199242, percent error 84.60
# Epoch     1, train loss 1.809261, train error 72.68,  val loss 1.826868, percent error 76.10
# Epoch     2, train loss 1.453269, train error 59.03,  val loss 1.472641, percent error 62.90
# Epoch     3, train loss 1.321747, train error 56.38,  val loss 1.335025, percent error 56.70
# Epoch     4, train loss 1.214618, train error 49.78,  val loss 1.241656, percent error 50.60
# Epoch     5, train loss 1.121500, train error 45.97,  val loss 1.171502, percent error 47.50
# Epoch     6, train loss 1.063051, train error 43.97,  val loss 1.105884, percent error 47.20
# Epoch     7, train loss 0.980582, train error 39.97,  val loss 0.999708, percent error 42.20
# Epoch     8, train loss 0.814180, train error 32.40,  val loss 0.863039, percent error 35.40
# Epoch     9, train loss 0.780967, train error 30.97,  val loss 0.821222, percent error 33.30
# Epoch    10, train loss 0.678882, train error 26.70,  val loss 0.712861, percent error 27.40
# Epoch    11, train loss 0.634253, train error 24.10,  val loss 0.688149, percent error 25.80
# Epoch    12, train loss 0.557316, train error 20.62,  val loss 0.647933, percent error 23.90
# Epoch    13, train loss 0.538697, train error 19.57,  val loss 0.627189, percent error 22.70
# Epoch    14, train loss 0.472214, train error 17.30,  val loss 0.581320, percent error 20.70
# Epoch    15, train loss 0.417089, train error 15.22,  val loss 0.520282, percent error 17.70
# Epoch    16, train loss 0.355161, train error 12.43,  val loss 0.467849, percent error 16.80
# Epoch    17, train loss 0.279589, train error 10.00,  val loss 0.401909, percent error 13.60
# Epoch    18, train loss 0.227023, train error 7.78,  val loss 0.369265, percent error 12.10
# Epoch    19, train loss 0.211634, train error 7.35,  val loss 0.382476, percent error 12.30
# Epoch    20, train loss 0.161218, train error 5.15,  val loss 0.332056, percent error 10.90
# Epoch    21, train loss 0.167452, train error 5.28,  val loss 0.367427, percent error 11.50
# Epoch    22, train loss 0.149502, train error 5.12,  val loss 0.347662, percent error 11.00
# Epoch    23, train loss 0.139478, train error 4.65,  val loss 0.343997, percent error 11.00
# Epoch    24, train loss 0.118576, train error 3.47,  val loss 0.326734, percent error 10.10
# Epoch    25, train loss 0.122119, train error 3.90,  val loss 0.318008, percent error 10.20
# Epoch    26, train loss 0.143239, train error 5.22,  val loss 0.368818, percent error 11.10
# Epoch    27, train loss 0.115508, train error 3.65,  val loss 0.347876, percent error 10.90
# Epoch    28, train loss 0.108322, train error 3.40,  val loss 0.332730, percent error 9.90
# Epoch    29, train loss 0.106825, train error 3.65,  val loss 0.347885, percent error 10.60
# Epoch    30, train loss 0.106998, train error 3.70,  val loss 0.331078, percent error 9.80
# Epoch    31, train loss 0.086579, train error 2.68,  val loss 0.330429, percent error 9.70
# Epoch    32, train loss 0.111963, train error 3.75,  val loss 0.372593, percent error 11.10
# Epoch    33, train loss 0.081883, train error 2.55,  val loss 0.330755, percent error 9.50
# Epoch    34, train loss 0.079278, train error 2.38,  val loss 0.341124, percent error 9.60
# Epoch    35, train loss 0.084166, train error 2.57,  val loss 0.327268, percent error 9.50
# Epoch    36, train loss 0.088713, train error 3.05,  val loss 0.350827, percent error 9.50
# Epoch    37, train loss 0.092308, train error 3.00,  val loss 0.340912, percent error 9.70
# Epoch    38, train loss 0.078005, train error 2.43,  val loss 0.335161, percent error 9.30
# Epoch    39, train loss 0.082649, train error 2.88,  val loss 0.349439, percent error 9.90
# Epoch    40, train loss 0.059525, train error 1.78,  val loss 0.337314, percent error 9.50
# Epoch    41, train loss 0.056590, train error 1.47,  val loss 0.343689, percent error 9.60
# Epoch    42, train loss 0.052443, train error 1.47,  val loss 0.341994, percent error 9.50
# Epoch    43, train loss 0.053056, train error 1.28,  val loss 0.343180, percent error 9.60
# Epoch    44, train loss 0.051355, train error 1.38,  val loss 0.349307, percent error 9.40
# Epoch    45, train loss 0.051079, train error 1.40,  val loss 0.345625, percent error 9.20
# Epoch    46, train loss 0.058373, train error 1.62,  val loss 0.375484, percent error 9.90
# Epoch    47, train loss 0.047229, train error 1.15,  val loss 0.356909, percent error 9.40
# Epoch    48, train loss 0.051721, train error 1.35,  val loss 0.371455, percent error 9.70
# Epoch    49, train loss 0.044803, train error 0.93,  val loss 0.362249, percent error 9.30
# Epoch    50, train loss 0.045723, train error 1.15,  val loss 0.365472, percent error 9.10
# Epoch    51, train loss 0.045107, train error 1.05,  val loss 0.369419, percent error 9.20
# Epoch    52, train loss 0.044994, train error 0.97,  val loss 0.370343, percent error 8.90
# Epoch    53, train loss 0.042899, train error 0.95,  val loss 0.381801, percent error 9.70
# Epoch    54, train loss 0.040010, train error 0.82,  val loss 0.362021, percent error 9.20
# Epoch    55, train loss 0.041270, train error 0.75,  val loss 0.375936, percent error 9.40
# Epoch    56, train loss 0.037901, train error 0.75,  val loss 0.374538, percent error 8.60
# Epoch    57, train loss 0.036779, train error 0.62,  val loss 0.377027, percent error 9.00
# Epoch    58, train loss 0.037404, train error 0.78,  val loss 0.380363, percent error 9.20
# Epoch    59, train loss 0.037624, train error 0.72,  val loss 0.382403, percent error 9.50
# Epoch    60, train loss 0.034009, train error 0.50,  val loss 0.383810, percent error 8.90
# Epoch    61, train loss 0.034051, train error 0.53,  val loss 0.384553, percent error 8.90
# Epoch    62, train loss 0.037063, train error 0.72,  val loss 0.392764, percent error 9.40
# Epoch    63, train loss 0.034346, train error 0.45,  val loss 0.392139, percent error 9.60
# Epoch    64, train loss 0.033027, train error 0.43,  val loss 0.389999, percent error 9.20
# Epoch    65, train loss 0.032862, train error 0.53,  val loss 0.389257, percent error 9.30
# Epoch    66, train loss 0.031937, train error 0.45,  val loss 0.388989, percent error 8.90
# Epoch    67, train loss 0.032490, train error 0.55,  val loss 0.397344, percent error 8.90
# Epoch    68, train loss 0.031050, train error 0.38,  val loss 0.389729, percent error 9.00
# Epoch    69, train loss 0.030892, train error 0.45,  val loss 0.394867, percent error 9.00
# Epoch    70, train loss 0.030743, train error 0.43,  val loss 0.392368, percent error 8.90
# Epoch    71, train loss 0.030210, train error 0.40,  val loss 0.399264, percent error 9.00
# Epoch    72, train loss 0.030450, train error 0.55,  val loss 0.395235, percent error 9.40
# Epoch    73, train loss 0.029662, train error 0.43,  val loss 0.399060, percent error 9.10
# Epoch    74, train loss 0.031094, train error 0.57,  val loss 0.401844, percent error 9.20
# Epoch    75, train loss 0.029215, train error 0.40,  val loss 0.403799, percent error 9.10
# Epoch    76, train loss 0.029194, train error 0.35,  val loss 0.406356, percent error 9.30
# Epoch    77, train loss 0.028936, train error 0.30,  val loss 0.402399, percent error 9.20
# Epoch    78, train loss 0.029025, train error 0.35,  val loss 0.406578, percent error 9.20
# Epoch    79, train loss 0.028296, train error 0.32,  val loss 0.408530, percent error 9.00
# Epoch    80, train loss 0.027648, train error 0.32,  val loss 0.406979, percent error 9.10
# Epoch    81, train loss 0.027871, train error 0.28,  val loss 0.407856, percent error 9.30
# Epoch    82, train loss 0.027516, train error 0.28,  val loss 0.405378, percent error 8.90
# Epoch    83, train loss 0.027199, train error 0.32,  val loss 0.405521, percent error 9.10
# Epoch    84, train loss 0.027270, train error 0.35,  val loss 0.411374, percent error 9.30
# Epoch    85, train loss 0.027089, train error 0.25,  val loss 0.408191, percent error 8.90
# Epoch    86, train loss 0.026938, train error 0.30,  val loss 0.408967, percent error 9.10
# Epoch    87, train loss 0.026731, train error 0.25,  val loss 0.411074, percent error 9.00
# Epoch    88, train loss 0.026795, train error 0.30,  val loss 0.408132, percent error 9.20
# Epoch    89, train loss 0.026583, train error 0.35,  val loss 0.410584, percent error 9.20
# Epoch    90, train loss 0.026667, train error 0.25,  val loss 0.412640, percent error 9.20
# Epoch    91, train loss 0.026670, train error 0.40,  val loss 0.409719, percent error 9.40
# Epoch    92, train loss 0.026002, train error 0.28,  val loss 0.412425, percent error 8.90
# Epoch    93, train loss 0.026070, train error 0.25,  val loss 0.415730, percent error 9.10
# Epoch    94, train loss 0.025789, train error 0.28,  val loss 0.414448, percent error 9.10
# Epoch    95, train loss 0.025850, train error 0.25,  val loss 0.414241, percent error 9.10
# Epoch    96, train loss 0.025944, train error 0.28,  val loss 0.415302, percent error 9.10
# Epoch    97, train loss 0.025584, train error 0.35,  val loss 0.414857, percent error 9.20
# Epoch    98, train loss 0.025483, train error 0.28,  val loss 0.415249, percent error 9.30
# Epoch    99, train loss 0.025721, train error 0.25,  val loss 0.418603, percent error 9.00
