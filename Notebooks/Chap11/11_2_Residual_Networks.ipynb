# %% [markdown]
# <a href="https://colab.research.google.com/github/dgsjackson/udl-prince-notebooks/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-twx991gx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-twx991gx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = self.linear2(h1.relu()) + h1
    h3 = self.linear3(h2.relu()) + h2
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.711795, train error 64.07,  val loss 1.804621, percent error 68.10
# Epoch     1, train loss 1.199070, train error 44.58,  val loss 1.358799, percent error 52.40
# Epoch     2, train loss 1.031411, train error 39.00,  val loss 1.202000, percent error 48.30
# Epoch     3, train loss 0.935936, train error 35.53,  val loss 1.256645, percent error 46.90
# Epoch     4, train loss 0.824985, train error 30.70,  val loss 1.222754, percent error 44.20
# Epoch     5, train loss 0.758633, train error 28.90,  val loss 1.185263, percent error 42.50
# Epoch     6, train loss 0.683091, train error 26.32,  val loss 1.133867, percent error 40.70
# Epoch     7, train loss 0.588441, train error 22.53,  val loss 1.191976, percent error 41.80
# Epoch     8, train loss 0.601860, train error 23.20,  val loss 1.212189, percent error 41.40
# Epoch     9, train loss 0.518763, train error 19.30,  val loss 1.152915, percent error 37.30
# Epoch    10, train loss 0.503951, train error 18.38,  val loss 1.225087, percent error 38.80
# Epoch    11, train loss 0.455679, train error 16.28,  val loss 1.249736, percent error 39.20
# Epoch    12, train loss 0.414553, train error 15.93,  val loss 1.325264, percent error 38.40
# Epoch    13, train loss 0.486797, train error 17.05,  val loss 1.514356, percent error 41.20
# Epoch    14, train loss 0.408253, train error 14.75,  val loss 1.454700, percent error 38.50
# Epoch    15, train loss 0.417446, train error 14.60,  val loss 1.433414, percent error 37.60
# Epoch    16, train loss 0.440513, train error 15.45,  val loss 1.645905, percent error 42.00
# Epoch    17, train loss 0.327955, train error 12.12,  val loss 1.411507, percent error 36.10
# Epoch    18, train loss 0.382861, train error 14.03,  val loss 1.714315, percent error 36.70
# Epoch    19, train loss 0.315954, train error 11.80,  val loss 1.588632, percent error 37.70
# Epoch    20, train loss 0.084902, train error 2.32,  val loss 1.249918, percent error 32.00
# Epoch    21, train loss 0.048036, train error 0.72,  val loss 1.269656, percent error 32.20
# Epoch    22, train loss 0.029884, train error 0.15,  val loss 1.316315, percent error 32.00
# Epoch    23, train loss 0.019422, train error 0.00,  val loss 1.340255, percent error 32.10
# Epoch    24, train loss 0.015261, train error 0.00,  val loss 1.394947, percent error 32.00
# Epoch    25, train loss 0.013040, train error 0.00,  val loss 1.423898, percent error 32.50
# Epoch    26, train loss 0.010683, train error 0.00,  val loss 1.449047, percent error 31.80
# Epoch    27, train loss 0.009414, train error 0.00,  val loss 1.479306, percent error 32.70
# Epoch    28, train loss 0.008372, train error 0.00,  val loss 1.493754, percent error 32.60
# Epoch    29, train loss 0.007495, train error 0.00,  val loss 1.516357, percent error 32.70
# Epoch    30, train loss 0.006791, train error 0.00,  val loss 1.536566, percent error 33.10
# Epoch    31, train loss 0.006225, train error 0.00,  val loss 1.554465, percent error 32.90
# Epoch    32, train loss 0.005740, train error 0.00,  val loss 1.570070, percent error 33.10
# Epoch    33, train loss 0.005328, train error 0.00,  val loss 1.585653, percent error 33.10
# Epoch    34, train loss 0.004964, train error 0.00,  val loss 1.602153, percent error 33.10
# Epoch    35, train loss 0.004653, train error 0.00,  val loss 1.615742, percent error 33.20
# Epoch    36, train loss 0.004379, train error 0.00,  val loss 1.631644, percent error 33.20
# Epoch    37, train loss 0.004110, train error 0.00,  val loss 1.642570, percent error 33.70
# Epoch    38, train loss 0.003893, train error 0.00,  val loss 1.653870, percent error 33.60
# Epoch    39, train loss 0.003692, train error 0.00,  val loss 1.666290, percent error 33.50
# Epoch    40, train loss 0.003593, train error 0.00,  val loss 1.671066, percent error 33.50
# Epoch    41, train loss 0.003505, train error 0.00,  val loss 1.676740, percent error 33.40
# Epoch    42, train loss 0.003423, train error 0.00,  val loss 1.682966, percent error 33.50
# Epoch    43, train loss 0.003342, train error 0.00,  val loss 1.685698, percent error 33.50
# Epoch    44, train loss 0.003266, train error 0.00,  val loss 1.690864, percent error 33.60
# Epoch    45, train loss 0.003194, train error 0.00,  val loss 1.696640, percent error 33.60
# Epoch    46, train loss 0.003123, train error 0.00,  val loss 1.700805, percent error 33.40
# Epoch    47, train loss 0.003055, train error 0.00,  val loss 1.705467, percent error 33.40
# Epoch    48, train loss 0.002991, train error 0.00,  val loss 1.709298, percent error 33.60
# Epoch    49, train loss 0.002929, train error 0.00,  val loss 1.714207, percent error 33.50
# Epoch    50, train loss 0.002869, train error 0.00,  val loss 1.718969, percent error 33.50
# Epoch    51, train loss 0.002812, train error 0.00,  val loss 1.723051, percent error 33.50
# Epoch    52, train loss 0.002756, train error 0.00,  val loss 1.727886, percent error 33.50
# Epoch    53, train loss 0.002702, train error 0.00,  val loss 1.731826, percent error 33.40
# Epoch    54, train loss 0.002651, train error 0.00,  val loss 1.734733, percent error 33.50
# Epoch    55, train loss 0.002603, train error 0.00,  val loss 1.739736, percent error 33.40
# Epoch    56, train loss 0.002553, train error 0.00,  val loss 1.743907, percent error 33.50
# Epoch    57, train loss 0.002506, train error 0.00,  val loss 1.747734, percent error 33.50
# Epoch    58, train loss 0.002462, train error 0.00,  val loss 1.751223, percent error 33.50
# Epoch    59, train loss 0.002419, train error 0.00,  val loss 1.755639, percent error 33.50
# Epoch    60, train loss 0.002397, train error 0.00,  val loss 1.757265, percent error 33.50
# Epoch    61, train loss 0.002376, train error 0.00,  val loss 1.759256, percent error 33.50
# Epoch    62, train loss 0.002356, train error 0.00,  val loss 1.761138, percent error 33.50
# Epoch    63, train loss 0.002336, train error 0.00,  val loss 1.762582, percent error 33.50
# Epoch    64, train loss 0.002316, train error 0.00,  val loss 1.764530, percent error 33.50
# Epoch    65, train loss 0.002296, train error 0.00,  val loss 1.766419, percent error 33.50
# Epoch    66, train loss 0.002278, train error 0.00,  val loss 1.768032, percent error 33.60
# Epoch    67, train loss 0.002259, train error 0.00,  val loss 1.769784, percent error 33.50
# Epoch    68, train loss 0.002240, train error 0.00,  val loss 1.771550, percent error 33.60
# Epoch    69, train loss 0.002222, train error 0.00,  val loss 1.773371, percent error 33.50
# Epoch    70, train loss 0.002204, train error 0.00,  val loss 1.775321, percent error 33.60
# Epoch    71, train loss 0.002186, train error 0.00,  val loss 1.776922, percent error 33.50
# Epoch    72, train loss 0.002168, train error 0.00,  val loss 1.778485, percent error 33.50
# Epoch    73, train loss 0.002151, train error 0.00,  val loss 1.780238, percent error 33.60
# Epoch    74, train loss 0.002135, train error 0.00,  val loss 1.782036, percent error 33.60
# Epoch    75, train loss 0.002118, train error 0.00,  val loss 1.783579, percent error 33.60
# Epoch    76, train loss 0.002101, train error 0.00,  val loss 1.785030, percent error 33.60
# Epoch    77, train loss 0.002085, train error 0.00,  val loss 1.786989, percent error 33.60
# Epoch    78, train loss 0.002069, train error 0.00,  val loss 1.788322, percent error 33.60
# Epoch    79, train loss 0.002053, train error 0.00,  val loss 1.790015, percent error 33.50
# Epoch    80, train loss 0.002045, train error 0.00,  val loss 1.790887, percent error 33.60
# Epoch    81, train loss 0.002037, train error 0.00,  val loss 1.791834, percent error 33.50
# Epoch    82, train loss 0.002030, train error 0.00,  val loss 1.792700, percent error 33.50
# Epoch    83, train loss 0.002022, train error 0.00,  val loss 1.793425, percent error 33.60
# Epoch    84, train loss 0.002015, train error 0.00,  val loss 1.794227, percent error 33.50
# Epoch    85, train loss 0.002007, train error 0.00,  val loss 1.794997, percent error 33.50
# Epoch    86, train loss 0.002000, train error 0.00,  val loss 1.795822, percent error 33.60
# Epoch    87, train loss 0.001992, train error 0.00,  val loss 1.796676, percent error 33.50
# Epoch    88, train loss 0.001985, train error 0.00,  val loss 1.797423, percent error 33.50
# Epoch    89, train loss 0.001977, train error 0.00,  val loss 1.798334, percent error 33.50
# Epoch    90, train loss 0.001970, train error 0.00,  val loss 1.798943, percent error 33.40
# Epoch    91, train loss 0.001963, train error 0.00,  val loss 1.799829, percent error 33.50
# Epoch    92, train loss 0.001956, train error 0.00,  val loss 1.800505, percent error 33.50
# Epoch    93, train loss 0.001949, train error 0.00,  val loss 1.801356, percent error 33.50
# Epoch    94, train loss 0.001941, train error 0.00,  val loss 1.802044, percent error 33.40
# Epoch    95, train loss 0.001935, train error 0.00,  val loss 1.802852, percent error 33.40
# Epoch    96, train loss 0.001928, train error 0.00,  val loss 1.803568, percent error 33.40
# Epoch    97, train loss 0.001921, train error 0.00,  val loss 1.804278, percent error 33.40
# Epoch    98, train loss 0.001914, train error 0.00,  val loss 1.805279, percent error 33.40
# Epoch    99, train loss 0.001907, train error 0.00,  val loss 1.805924, percent error 33.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
